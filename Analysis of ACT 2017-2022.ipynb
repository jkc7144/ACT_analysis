# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# For the ACT,
# 1. Does the participation rate influence ACT scores?
# 2. Are there overlaps in the ACT subjects, and are the scores related to each other? If yes, do we need to review the format of the ACT?
#
# Target Audience: State education departments

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# In October 2022, ACT reported that the 2022 average ACT score has declined to the lowest level in more than 30 years. The report indicated that high school students are not meeting college-readiness benchmarks, signaling systemic failures in the American education that were exacerbated by the pandemic. ([*source*](https://leadershipblog.act.org/2022/10/GradClassRelease2022.html))
#
# The ACT is one of the standardized tests for colleges admissions the United States. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not students are accepted into a university.
#
# Presently 16 out of 50 states and the District of Columbia (DC) require all students to take the ACT as part of statewide testing programs - meaning the tests are offered for free in these states. Seven additional states also fund these tests on optional basis, allowing their students to take the tests for free. Meanwhile, 20 states including DC have started working with the College Board to administer SAT for free. ([*source*](https://blog.prepscholar.com/which-states-require-the-sat))
#
# There are 4 sections in the ACT: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). Meanwhile in the other standardized tests, SAT, only has two sections in the test: Evidence-Based Reading & Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). While both tests have different formats and score ranges, the ACT is generally considered more content, particularly the Science section.
#
# However, standardized tests continues to be a controversial topic for students, administrators, and legislators. Supporters of these tests argue that these scores are an objective measure to determine college admittance and provides a push to students to perform academically. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools around the US have opted to drop the SAT/ACT requirement. ([*source*](https://www.virginiamercury.com/2022/10/31/more-virginia-colleges-make-sat-act-exams-optional/))
#
# Before we hold the American education system and parents (or anyone else) accountable for the declining test scores, the first thing we need to figure out is - are test scores really on a decline, per the reports by ACT?

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# This research will cover ACT scores from 2017 to 2022, to ensure a fair analysis that also includes the pre-pandemic period. The datasets used for this research are:
# - [`act_2017.csv`](./datasets/act_2017.csv): 2017 ACT Scores by State, provided as part of this project package
# - [`act_2018.csv`](./datasets/act_2018_v2.csv): 2018 ACT Scores by State, taken from the U.S. Department of Education, National Center for Education Statistics ([*source*](https://nces.ed.gov/programs/digest/d18/tables/dt18_226.60.asp))
# - [`act_2019.csv`](./datasets/act_2019_v2.csv): 2019 ACT Scores by State, taken from the U.S. Department of Education, National Center for Education Statistics ([*source*](https://nces.ed.gov/programs/digest/d19/tables/dt19_226.60.asp))
# - [`act_2020.csv`](./datasets/act_2020.csv): 2020 ACT Scores by State, taken from the U.S. Department of Education, National Center for Education Statistics ([*source*](https://nces.ed.gov/programs/digest/d20/tables/dt20_226.60.asp))
# - [`act_2021.csv`](./datasets/act_2021.csv): 2021 ACT Scores by State, taken from the U.S. Department of Education, National Center for Education Statistics ([*source*](https://nces.ed.gov/programs/digest/d21/tables/dt21_226.60.asp))
# - [`act_2022.csv`](./datasets/act_2022.csv): 2022 ACT Scores by State, taken from ACT ([*source*](https://www.act.org/content/dam/act/unsecured/documents/2022/2022-Average-ACT-Scores-by-State.pdf))

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# Additional research and reading:
# - 2022 ACT National Profile Report ([*source*](https://www.act.org/content/dam/act/unsecured/documents/2022/2022-National-ACT-Profile-Report.pdf))
# - 2022 ACT average score press release ([*source*](https://leadershipblog.act.org/2022/10/GradClassRelease2022.html))
# - ABC article on lowest ACT score ([*source*](https://abcnews.go.com/US/high-school-class-2022-lowest-act-scores-30/story?id=91497084))
# - Fortune article on worst test score ([*source*](https://fortune.com/2022/10/12/act-college-admissions-scores-high-school-graduates-worst-30-years/))
# - Bloomberg opinion editorial on standardized testing ([*source*](https://www.bloomberg.com/opinion/articles/2022-10-26/us-colleges-should-bring-back-sat-and-act-test-requirements?srnd=opinion))
# - Bloomberg article on the rate of test submissions in college applications ([*source*](https://www.bloomberg.com/news/articles/2022-01-24/wealthy-teens-tout-test-results-colleges-no-longer-require))
# - More than 1,700 US colleges enforcing test-optional for Fall 2023 ([*source*](https://www.highereddive.com/news/over-1700-colleges-wont-require-sat-act-for-fall-2023-up-from-same-poin/628267/))
# - More Virginia colleges enforcing test-optional policy ([*source*](https://www.virginiamercury.com/2022/10/31/more-virginia-colleges-make-sat-act-exams-optional/))
# - Maine revamping standardized tests ([*source*](https://www.mainepublic.org/maine/2021-02-02/maine-schools-plan-to-administer-revamped-standardized-tests-after-shelving-them-during-pandemic))
# - List of standardized tests by state ([*source*](https://educationadvanced.com/resources/blog/list-of-standardized-tests-by-state/))
# - About the ACT Science Section ([*source*](https://www.usnews.com/education/blogs/college-admissions-playbook/articles/what-to-know-about-the-act-science-section))
# - US map of ACT 2022 participation rate from ACT 2022 Data Visualization: ([*source*](https://tableauprototypes.act.org/t/ACTExternal/views/ACTProfileReport2022/PercentTestedbyState?%3Aembed=y&%3Adisplay_count=n&%3AshowVizHome=n&%3Aorigin=viz_share_link))

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# This is a formula to calculate the mean of values in a list

def avg_list(numlist):
    return sum(numlist)/len(numlist)

# %%
# Sample list to test the average function

list_1 = [20,30,40,50,60]

avg_list(list_1)
# Out:
# 40.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# This is a formula to calculate the standard deviation of a list

def stdev_list(numlist):
    var = sum((v - avg_list(numlist))**2 for v in numlist) / len(numlist)
    stdev = var ** 0.5
    return stdev

# %%
# Sample run to test the standard deviation function

stdev_list(list_1)
# Out:
# 14.142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# This is a formula to convert string percentages into float

def percent_to_float(percentage):
    return float(percentage.replace("%", "")) / 100

# %%
# Sample run to test the conversion function

percent_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### *ACT 2017 Scores:*

# %%
# This opens and prints the first five rows of the 2017 ACT data by state.
# Data Source: part of project package provided

scores_2017 = pd.read_csv('datasets/act_2017.csv')
scores_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# This formula checks for missing values or unexpected types.

scores_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
# This formula changes all strings to floats in the Participation column, using above formula.

scores_2017['Participation'] = scores_2017['Participation'].map(percent_to_float)

# %%
# When changing strings to flaots in column Composit e, there was an error on line 51. Here's the formula to correct the cell.

scores_2017.iloc[51,6] = scores_2017.iloc[51,6].strip('x')
scores_2017.iloc[51,6]
# Out:
# '20.2'

# %%
# Maryland's Science score was incorrectly input as 2.3. Based on the data from the U.S. Department of Education, National Center for Education Statistics, the actual number is 23.2. Hence this formula will correct the cell. 

scores_2017.iloc[21,5] = 23.2
scores_2017.iloc[21,5]
# Out:
# 23.2

# %%
# And now, to change all strings to floats in the Composite column.

scores_2017['Composite'] = scores_2017['Composite'].astype(float)

# %%
# Check to ensure the Participation and Composite columns are floats.

scores_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
# This formula changes the column name to lowercase.

scores_2017.columns = scores_2017.columns.str.lower()
scores_2017.head()
# Out:
#       state  participation  english  math  reading  science  composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %%
# Renaming the columns to avoid duplicate column names when merging dataframes later. 'State' for 2017 will be retained while the rest will be changed.

scores_2017.rename(columns={
    'participation': 'part_17',
    'english': 'eng_17',
    'math': 'math_17',
    'reading': 'read_17',
    'science': 'sci_17',
    'composite': 'comp_17'
}, inplace=True)

# %%
scores_2017.head()
# Out:
#       state  part_17  eng_17  math_17  read_17  sci_17  comp_17
# 0  National     0.60    20.3     20.7     21.4    21.0     21.0
# 1   Alabama     1.00    18.9     18.4     19.7    19.4     19.2
# 2    Alaska     0.65    18.7     19.8     20.4    19.9     19.8
# 3   Arizona     0.62    18.6     19.8     20.1    19.8     19.7
# 4  Arkansas     1.00    18.9     19.0     19.7    19.5     19.4

# %% [markdown]
# ### *ACT 2018 Scores:*

# %%
# This opens and prints the first five rows of the 2018 ACT data by state. The data was obtained through external source for detailed breakdown of students' scores.
# Data Source: ACT, The Condition of College and Career Readiness, 2014 and 2018. U.S. Department of Education, National Center for Education Statistics, Private School Universe Survey (PSS), 2014; and National High School Graduates Projection Model, 1972-73 through 2028-29. (This table was prepared March 2019.)

scores_2018 = pd.read_csv('datasets/act_2018_v2.csv')
scores_2018.head()
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 0   National             52     20.2  20.5     21.3     20.7       20.8
# 1   Alabama             100     18.9  18.3     19.6     19.0       19.1
# 2    Alaska              33     19.8  20.6     21.6     20.7       20.8
# 3   Arizona              66     18.2  19.4     19.5     19.2       19.2
# 4  Arkansas             100     19.1  18.9     19.7     19.4       19.4

# %%
# This formula checks for missing values or unexpected types.

scores_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB

# %%
# This formula changes all strings to floats in the Participation column. 

scores_2018['Participation'] = scores_2018['Participation'].astype(float)

# %%
# This additional step changes the values in the Participation column to decimal, in line with the 2017 data.

scores_2018['Participation'] = scores_2018['Participation'].div(100)

# %%
# Check to ensure the Participation column is a float.

scores_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
# This is the formula to change the column name to lowercase.

scores_2018.columns = scores_2018.columns.str.lower()
scores_2018.head()
# Out:
#        state  participation  english  math  reading  science  composite
# 0   National           0.52     20.2  20.5     21.3     20.7       20.8
# 1   Alabama            1.00     18.9  18.3     19.6     19.0       19.1
# 2    Alaska            0.33     19.8  20.6     21.6     20.7       20.8
# 3   Arizona            0.66     18.2  19.4     19.5     19.2       19.2
# 4  Arkansas            1.00     19.1  18.9     19.7     19.4       19.4

# %%
# Renaming the columns to avoid duplicate column names when merging dataframes later.

scores_2018.rename(columns={
    'state': 'st_18',
    'participation': 'part_18',
    'english': 'eng_18',
    'math': 'math_18',
    'reading': 'read_18',
    'science': 'sci_18',
    'composite': 'comp_18'
}, inplace=True)

# %%
scores_2018.head()
# Out:
#        st_18  part_18  eng_18  math_18  read_18  sci_18  comp_18
# 0   National     0.52    20.2     20.5     21.3    20.7     20.8
# 1   Alabama      1.00    18.9     18.3     19.6    19.0     19.1
# 2    Alaska      0.33    19.8     20.6     21.6    20.7     20.8
# 3   Arizona      0.66    18.2     19.4     19.5    19.2     19.2
# 4  Arkansas      1.00    19.1     18.9     19.7    19.4     19.4

# %% [markdown]
# ### *ACT 2019 Scores:*

# %%
# This opens and prints the first five rows of the 2019 ACT data by state. The data was obtained through external source for detailed breakdown of students' scores.
# Data Source: ACT, The Condition of College and Career Readiness, 2015 and 2019. U.S. Department of Education, National Center for Education Statistics, National High School Graduates Projection Model, 1972-73 through 2029-30. (This table was prepared January 2020.)

scores_2019 = pd.read_csv('datasets/act_2019_v2.csv')
scores_2019.head()
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 0   National             48     20.1  20.4     21.2     20.6       20.7
# 1   Alabama             100     18.7  18.1     19.5     18.8       18.9
# 2    Alaska              38     18.9  19.9     20.9     20.2       20.1
# 3   Arizona              73     17.9  19.2     19.3     19.0       19.0
# 4  Arkansas             100     19.0  18.7     19.6     19.2       19.3

# %%
# This formula checks for missing values or unexpected types.

scores_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB

# %%
# This formula changes all strings to floats in the Participation column. 

scores_2019['Participation'] = scores_2019['Participation'].astype(float)

# %%
# This additional step changes the values in the Participation column to decimal, in line with the 2017 data.

scores_2019['Participation'] = scores_2019['Participation'].div(100)

# %%
# Check to ensure the Participation column is a float.

scores_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
# This is the formula to change the column name to lowercase.

scores_2019.columns = scores_2019.columns.str.lower()
scores_2019.head()
# Out:
#        state  participation  english  math  reading  science  composite
# 0   National           0.48     20.1  20.4     21.2     20.6       20.7
# 1   Alabama            1.00     18.7  18.1     19.5     18.8       18.9
# 2    Alaska            0.38     18.9  19.9     20.9     20.2       20.1
# 3   Arizona            0.73     17.9  19.2     19.3     19.0       19.0
# 4  Arkansas            1.00     19.0  18.7     19.6     19.2       19.3

# %%
# Renaming the columns to avoid duplicate column names when merging dataframes later.

scores_2019.rename(columns={
    'state': 'st_19',
    'participation': 'part_19',
    'english': 'eng_19',
    'math': 'math_19',
    'reading': 'read_19',
    'science': 'sci_19',
    'composite': 'comp_19'
}, inplace=True)

# %%
scores_2019.head()
# Out:
#        st_19  part_19  eng_19  math_19  read_19  sci_19  comp_19
# 0   National     0.48    20.1     20.4     21.2    20.6     20.7
# 1   Alabama      1.00    18.7     18.1     19.5    18.8     18.9
# 2    Alaska      0.38    18.9     19.9     20.9    20.2     20.1
# 3   Arizona      0.73    17.9     19.2     19.3    19.0     19.0
# 4  Arkansas      1.00    19.0     18.7     19.6    19.2     19.3

# %% [markdown]
# ### *ACT 2020 Scores:*

# %%
# This opens and prints the first five rows of the 2020 ACT data by state. The data was obtained through external source for latest breakdown.
# Data Source: ACT, The Condition of College and Career Readiness, 2016 and 2020. U.S. Department of Education, National Center for Education Statistics, National High School Graduates Projection Model, 1972-73 through 2029-30. (This table was prepared June 2021.)

scores_2020 = pd.read_csv('datasets/act_2020.csv')
scores_2020.head()
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 0   National             46     20.1  20.4     21.2     20.6       20.7
# 1   Alabama             100     18.5  18.1     19.3     18.8       18.8
# 2    Alaska              33     18.8  20.0     21.0     20.1       20.1
# 3   Arizona              71     18.0  19.3     19.5     19.1       19.1
# 4  Arkansas             100     18.7  18.4     19.4     19.1       19.0

# %%
# This formula checks for missing values or unexpected types.

scores_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB

# %%
# This formula changes all strings to floats in the Participation column. 

scores_2020['Participation'] = scores_2020['Participation'].astype(float)

# %%
# This additional step changes the values in the Participation column to decimal, in line with the 2017 data.

scores_2020['Participation'] = scores_2020['Participation'].div(100)

# %%
# Check to ensure the Participation column is a float.

scores_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
# This is the formula to change the column name to lowercase.

scores_2020.columns = scores_2020.columns.str.lower()
scores_2020.head()
# Out:
#        state  participation  english  math  reading  science  composite
# 0   National           0.46     20.1  20.4     21.2     20.6       20.7
# 1   Alabama            1.00     18.5  18.1     19.3     18.8       18.8
# 2    Alaska            0.33     18.8  20.0     21.0     20.1       20.1
# 3   Arizona            0.71     18.0  19.3     19.5     19.1       19.1
# 4  Arkansas            1.00     18.7  18.4     19.4     19.1       19.0

# %%
# Renaming the columns to avoid duplicate column names when merging dataframes later.

scores_2020.rename(columns={
    'state': 'st_20',
    'participation': 'part_20',
    'english': 'eng_20',
    'math': 'math_20',
    'reading': 'read_20',
    'science': 'sci_20',
    'composite': 'comp_20'
}, inplace=True)

# %%
scores_2020.head()
# Out:
#        st_20  part_20  eng_20  math_20  read_20  sci_20  comp_20
# 0   National     0.46    20.1     20.4     21.2    20.6     20.7
# 1   Alabama      1.00    18.5     18.1     19.3    18.8     18.8
# 2    Alaska      0.33    18.8     20.0     21.0    20.1     20.1
# 3   Arizona      0.71    18.0     19.3     19.5    19.1     19.1
# 4  Arkansas      1.00    18.7     18.4     19.4    19.1     19.0

# %% [markdown]
# ### *ACT 2021 Scores:*

# %%
# This opens and prints the first five rows of the 2021 ACT data by state. The data was obtained through external source for latest breakdown.
# Data Source: ACT, The Condition of College and Career Readiness, 2017 and 2021. U.S. Department of Education, National Center for Education Statistics, National High School Graduates Projection Model, through 2030-31. (This table was prepared December 2021.)

scores_2021 = pd.read_csv('datasets/act_2021.csv')
scores_2021.head()
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 0   National             35     19.6  19.9     20.9     20.4       20.3
# 1   Alabama             100     18.4  18.0     19.2     18.8       18.7
# 2    Alaska              16     19.4  20.5     21.6     20.6       20.6
# 3   Arizona              35     18.6  19.8     20.3     19.9       19.8
# 4  Arkansas              99     18.6  18.3     19.3     19.2       19.0

# %%
# This formula checks for missing values or unexpected types.

scores_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB

# %%
# This formula changes all integer to floats in the Participation column. 

scores_2021['Participation'] = scores_2021['Participation'].astype(float)

# %%
# This additional step changes the values in the Participation column to decimal, in line with the 2017 data.

scores_2021['Participation'] = scores_2021['Participation'].div(100)

# %%
# Check to ensure the Participation column is a float.

scores_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
# This is the formula to change the column name to lowercase.

scores_2021.columns = scores_2021.columns.str.lower()
scores_2021.head()
# Out:
#        state  participation  english  math  reading  science  composite
# 0   National           0.35     19.6  19.9     20.9     20.4       20.3
# 1   Alabama            1.00     18.4  18.0     19.2     18.8       18.7
# 2    Alaska            0.16     19.4  20.5     21.6     20.6       20.6
# 3   Arizona            0.35     18.6  19.8     20.3     19.9       19.8
# 4  Arkansas            0.99     18.6  18.3     19.3     19.2       19.0

# %%
# Renaming the columns to avoid duplicate column names when merging dataframes later.

scores_2021.rename(columns={
    'state': 'st_21',
    'participation': 'part_21',
    'english': 'eng_21',
    'math': 'math_21',
    'reading': 'read_21',
    'science': 'sci_21',
    'composite': 'comp_21'
}, inplace=True)

# %%
scores_2021.head()
# Out:
#        st_21  part_21  eng_21  math_21  read_21  sci_21  comp_21
# 0   National     0.35    19.6     19.9     20.9    20.4     20.3
# 1   Alabama      1.00    18.4     18.0     19.2    18.8     18.7
# 2    Alaska      0.16    19.4     20.5     21.6    20.6     20.6
# 3   Arizona      0.35    18.6     19.8     20.3    19.9     19.8
# 4  Arkansas      0.99    18.6     18.3     19.3    19.2     19.0

# %% [markdown]
# ### *ACT 2022 Scores:*

# %%
# This opens and prints the first five rows of the 2022 ACT data by state. The data was obtained through external source for latest breakdown.
# Data Source: ACT, 2022. Knocking at the College Door: Projections of High School Graduates, 9th edition. ©December 2016 by the Western Interstate Commission for Higher Education

scores_2022 = pd.read_csv('datasets/act_2022.csv')
scores_2022.head()
# Out:
#        State  Participation  English  Math  Reading  Science  Composite
# 0   National             36     19.0  19.3     20.4     19.9       19.8
# 1   Alabama             100     17.3  17.4     18.5     18.2       18.0
# 2    Alaska              14     19.3  20.0     21.4     20.4       20.4
# 3   Arizona              64     17.3  18.5     18.8     18.5       18.4
# 4  Arkansas              93     18.3  18.1     19.2     19.1       18.8

# %%
# This formula checks for missing values or unexpected types.

scores_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     int64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ KB

# %%
# This formula changes all integer to floats in the Participation column. 

scores_2022['Participation'] = scores_2022['Participation'].astype(float)

# %%
# This additional step changes the values in the Participation column to decimal, in line with the 2017 data.

scores_2022['Participation'] = scores_2022['Participation'].div(100)

# %%
# Check to ensure the Participation column is a float.

scores_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
# This is the formula to change the column name to lowercase.

scores_2022.columns = scores_2022.columns.str.lower()
scores_2022.head()
# Out:
#        state  participation  english  math  reading  science  composite
# 0   National           0.36     19.0  19.3     20.4     19.9       19.8
# 1   Alabama            1.00     17.3  17.4     18.5     18.2       18.0
# 2    Alaska            0.14     19.3  20.0     21.4     20.4       20.4
# 3   Arizona            0.64     17.3  18.5     18.8     18.5       18.4
# 4  Arkansas            0.93     18.3  18.1     19.2     19.1       18.8

# %%
# Renaming the columns to avoid duplicate column names when merging dataframes later.

scores_2022.rename(columns={
    'state': 'st_22',
    'participation': 'part_22',
    'english': 'eng_22',
    'math': 'math_22',
    'reading': 'read_22',
    'science': 'sci_22',
    'composite': 'comp_22'
}, inplace=True)

# %%
scores_2021.head()
# Out:
#        st_21  part_21  eng_21  math_21  read_21  sci_21  comp_21
# 0   National     0.35    19.6     19.9     20.9    20.4     20.3
# 1   Alabama      1.00    18.4     18.0     19.2    18.8     18.7
# 2    Alaska      0.16    19.4     20.5     21.6    20.6     20.6
# 3   Arizona      0.35    18.6     19.8     20.3    19.9     19.8
# 4  Arkansas      0.99    18.6     18.3     19.3    19.2     19.0

# %% [markdown]
# ### *Merging datasets & creating new dataframes:*

# %%
# This formula concatenates all participation rate and scores from 2017 to 2021.

allscores = pd.concat([scores_2017, scores_2018, scores_2019, scores_2020, scores_2021, scores_2022], axis = 1, join = "inner")
allscores.head()
# Out:
#       state  part_17  eng_17  math_17  read_17  sci_17  comp_17      st_18  \
# 0  National     0.60    20.3     20.7     21.4    21.0     21.0   National
# 1   Alabama     1.00    18.9     18.4     19.7    19.4     19.2   Alabama
# 2    Alaska     0.65    18.7     19.8     20.4    19.9     19.8    Alaska
# 3   Arizona     0.62    18.6     19.8     20.1    19.8     19.7   Arizona
# 4  Arkansas     1.00    18.9     19.0     19.7    19.5     19.4  Arkansas
#
#    part_18  eng_18  ...  read_21  sci_21  comp_21      st_22 part_22  eng_22  \
# 0     0.52    20.2  ...     20.9    20.4     20.3   National    0.36    19.0
# 1     1.00    18.9  ...     19.2    18.8     18.7   Alabama     1.00    17.3
# 2     0.33    19.8  ...     21.6    20.6     20.6    Alaska     0.14    19.3
# 3     0.66    18.2  ...     20.3    19.9     19.8   Arizona     0.64    17.3
# 4     1.00    19.1  ...     19.3    19.2     19.0  Arkansas     0.93    18.3
#
#    math_22  read_22  sci_22  comp_22
# ...

# %%
# This formula removes the additional "state" columns as it is now redundant.

allscores.drop(['st_18', 'st_19', 'st_20', 'st_21', 'st_22'] , axis=1, inplace=True)
allscores.head()
# Out:
#       state  part_17  eng_17  math_17  read_17  sci_17  comp_17  part_18  \
# 0  National     0.60    20.3     20.7     21.4    21.0     21.0     0.52
# 1   Alabama     1.00    18.9     18.4     19.7    19.4     19.2     1.00
# 2    Alaska     0.65    18.7     19.8     20.4    19.9     19.8     0.33
# 3   Arizona     0.62    18.6     19.8     20.1    19.8     19.7     0.66
# 4  Arkansas     1.00    18.9     19.0     19.7    19.5     19.4     1.00
#
#    eng_18  math_18  ...  math_21  read_21  sci_21  comp_21  part_22  eng_22  \
# 0    20.2     20.5  ...     19.9     20.9    20.4     20.3     0.36    19.0
# 1    18.9     18.3  ...     18.0     19.2    18.8     18.7     1.00    17.3
# 2    19.8     20.6  ...     20.5     21.6    20.6     20.6     0.14    19.3
# 3    18.2     19.4  ...     19.8     20.3    19.9     19.8     0.64    17.3
# 4    19.1     18.9  ...     18.3     19.3    19.2     19.0     0.93    18.3
#
#    math_22  read_22  sci_22  comp_22
# ...

# %%
# Exporting All Scores dataframe into csv file.

allscores.to_csv('output/ACT_All_Scores.csv', index=False)

# %%
# This formula concatenates all participation rate from 2017 to 2021.

participation = pd.concat([scores_2017['state'], scores_2017['part_17'], scores_2018['part_18'], scores_2019['part_19'], scores_2020['part_20'], scores_2021['part_21'], scores_2022['part_22']], axis=1)
participation.head()
# Out:
#       state  part_17  part_18  part_19  part_20  part_21  part_22
# 0  National     0.60     0.52     0.48     0.46     0.35     0.36
# 1   Alabama     1.00     1.00     1.00     1.00     1.00     1.00
# 2    Alaska     0.65     0.33     0.38     0.33     0.16     0.14
# 3   Arizona     0.62     0.66     0.73     0.71     0.35     0.64
# 4  Arkansas     1.00     1.00     1.00     1.00     0.99     0.93

# %%
# Renaming the columns in the Participation dataframe.

participation.rename(columns={
    'part_17': '2017',
    'part_18': '2018',
    'part_19': '2019',
    'part_20': '2020',
    'part_21': '2021',
    'part_22': '2022'
}, inplace=True)

# %%
# Exporting the Participation dataframe into csv file.

participation.to_csv('output/ACT_Participation.csv', index=False)

# %%
# This formula concatenates all English scores from 2017 to 2021.

english = pd.concat([scores_2017['state'], scores_2017['eng_17'], scores_2018['eng_18'], scores_2019['eng_19'], scores_2020['eng_20'], scores_2021['eng_21'], scores_2022['eng_22']], axis=1)
english.head()
# Out:
#       state  eng_17  eng_18  eng_19  eng_20  eng_21  eng_22
# 0  National    20.3    20.2    20.1    20.1    19.6    19.0
# 1   Alabama    18.9    18.9    18.7    18.5    18.4    17.3
# 2    Alaska    18.7    19.8    18.9    18.8    19.4    19.3
# 3   Arizona    18.6    18.2    17.9    18.0    18.6    17.3
# 4  Arkansas    18.9    19.1    19.0    18.7    18.6    18.3

# %%
# Renaming the columns in the English scores dataframe.

english.rename(columns={
    'eng_17': '2017',
    'eng_18': '2018',
    'eng_19': '2019',
    'eng_20': '2020',
    'eng_21': '2021',
    'eng_22': '2022'
}, inplace=True)

# %%
# Exporting the English scores dataframe into csv file.

english.to_csv('output/ACT_English_scores.csv', index=False)

# %%
# This formula concatenates all Math scores from 2017 to 2021.

math = pd.concat([scores_2017['state'], scores_2017['math_17'], scores_2018['math_18'], scores_2019['math_19'], scores_2020['math_20'], scores_2021['math_21'], scores_2022['math_22']], axis=1)
math.head()
# Out:
#       state  math_17  math_18  math_19  math_20  math_21  math_22
# 0  National     20.7     20.5     20.4     20.4     19.9     19.3
# 1   Alabama     18.4     18.3     18.1     18.1     18.0     17.4
# 2    Alaska     19.8     20.6     19.9     20.0     20.5     20.0
# 3   Arizona     19.8     19.4     19.2     19.3     19.8     18.5
# 4  Arkansas     19.0     18.9     18.7     18.4     18.3     18.1

# %%
# Renaming the columns in the Math scores dataframe.

math.rename(columns={
    'math_17': '2017',
    'math_18': '2018',
    'math_19': '2019',
    'math_20': '2020',
    'math_21': '2021',
    'math_22': '2022'
}, inplace=True)

# %%
# Exporting the Math scores dataframe into csv file.

math.to_csv('output/ACT_Math_scores.csv', index=False)

# %%
# This formula concatenates all Reading scores from 2017 to 2021.

read = pd.concat([scores_2017['state'], scores_2017['read_17'], scores_2018['read_18'], scores_2019['read_19'], scores_2020['read_20'], scores_2021['read_21'], scores_2022['read_22']], axis=1)
read.head()
# Out:
#       state  read_17  read_18  read_19  read_20  read_21  read_22
# 0  National     21.4     21.3     21.2     21.2     20.9     20.4
# 1   Alabama     19.7     19.6     19.5     19.3     19.2     18.5
# 2    Alaska     20.4     21.6     20.9     21.0     21.6     21.4
# 3   Arizona     20.1     19.5     19.3     19.5     20.3     18.8
# 4  Arkansas     19.7     19.7     19.6     19.4     19.3     19.2

# %%
# Renaming the columns in the Reading scores dataframe.

read.rename(columns={
    'read_17': '2017',
    'read_18': '2018',
    'read_19': '2019',
    'read_20': '2020',
    'read_21': '2021',
    'read_22': '2022'
}, inplace=True)

# %%
# Exporting the Reading scores dataframe into csv file.

read.to_csv('output/ACT_Reading_scores.csv', index=False)

# %%
# This formula concatenates all Science scores from 2017 to 2021.

science = pd.concat([scores_2017['state'], scores_2017['sci_17'], scores_2018['sci_18'], scores_2019['sci_19'], scores_2020['sci_20'], scores_2021['sci_21'], scores_2022['sci_22']], axis=1)
science.head()
# Out:
#       state  sci_17  sci_18  sci_19  sci_20  sci_21  sci_22
# 0  National    21.0    20.7    20.6    20.6    20.4    19.9
# 1   Alabama    19.4    19.0    18.8    18.8    18.8    18.2
# 2    Alaska    19.9    20.7    20.2    20.1    20.6    20.4
# 3   Arizona    19.8    19.2    19.0    19.1    19.9    18.5
# 4  Arkansas    19.5    19.4    19.2    19.1    19.2    19.1

# %%
# Renaming the columns in the Science scores dataframe.

science.rename(columns={
    'sci_17': '2017',
    'sci_18': '2018',
    'sci_19': '2019',
    'sci_20': '2020',
    'sci_21': '2021',
    'sci_22': '2022'
}, inplace=True)

# %%
# Exporting the Science scores dataframe into csv file.

science.to_csv('output/ACT_Science_scores.csv', index=False)

# %%
# This formula concatenates all Composite scores from 2017 to 2021.

composite = pd.concat([scores_2017['state'], scores_2017['comp_17'], scores_2018['comp_18'], scores_2019['comp_19'], scores_2020['comp_20'], scores_2021['comp_21'], scores_2022['comp_22']], axis=1)
composite.head()
# Out:
#       state  comp_17  comp_18  comp_19  comp_20  comp_21  comp_22
# 0  National     21.0     20.8     20.7     20.7     20.3     19.8
# 1   Alabama     19.2     19.1     18.9     18.8     18.7     18.0
# 2    Alaska     19.8     20.8     20.1     20.1     20.6     20.4
# 3   Arizona     19.7     19.2     19.0     19.1     19.8     18.4
# 4  Arkansas     19.4     19.4     19.3     19.0     19.0     18.8

# %%
# Renaming the columns in the Composite scores dataframe.

composite.rename(columns={
    'comp_17': '2017',
    'comp_18': '2018',
    'comp_19': '2019',
    'comp_20': '2020',
    'comp_21': '2021',
    'comp_22': '2022'
}, inplace=True)

# %%
# Exporting the Composite scores dataframe into csv file.

composite.to_csv('output/ACT_Composite_scores.csv', index=False)

# %%
# This formula concatenates all National average scores from 2017 to 2022.

national = pd.concat([participation.loc[participation['state'] == 'National'], english.loc[english['state'] == 'National'], math.loc[math['state'] == 'National'], read.loc[read['state'] == 'National'], science.loc[science['state'] == 'National'], composite.loc[composite['state'] == 'National']], axis=0)
national.head()
# Out:
#       state  2017   2018   2019   2020   2021   2022
# 0  National   0.6   0.52   0.48   0.46   0.35   0.36
# 0  National  20.3  20.20  20.10  20.10  19.60  19.00
# 0  National  20.7  20.50  20.40  20.40  19.90  19.30
# 0  National  21.4  21.30  21.20  21.20  20.90  20.40
# 0  National  21.0  20.70  20.60  20.60  20.40  19.90

# %%
# This formula adds a new categorigcal column, "national avg".

national["national_avg"] = ['participation', 'english', 'math', 'reading', 'science', 'composite']

# %%
# This formula removes the "state" column as it is now redundant.

national.drop('state', axis=1, inplace=True)

# %%
# This column moves the "avg" column to the first position.

first_column = national.pop('national_avg')
national.insert(0, 'national_avg', first_column)

# %%
# Prints all National scores.

national
# Out:
#     national_avg  2017   2018   2019   2020   2021   2022
# 0  participation   0.6   0.52   0.48   0.46   0.35   0.36
# 0        english  20.3  20.20  20.10  20.10  19.60  19.00
# 0           math  20.7  20.50  20.40  20.40  19.90  19.30
# 0        reading  21.4  21.30  21.20  21.20  20.90  20.40
# 0        science  21.0  20.70  20.60  20.60  20.40  19.90
# 0      composite  21.0  20.80  20.70  20.70  20.30  19.80

# %%
# Exporting the National scores dataframe into csv file.

national.to_csv('output/ACT_National_scores.csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# Below is the list of data used:
#
# | Feature                        	| Type     	| Dataset         	| Description                                                        	|
# |--------------------------------	|----------	|-----------------	|--------------------------------------------------------------------	|
# | **state**                      	| _object_ 	| ACT 2017        	| All state names in the US                                          	|
# | **part_17**                    	| _float_  	| ACT 2017        	| The 2017 average participation rate in the ACT                     	|
# | **eng_17**                     	| _float_  	| ACT 2017        	| The 2017 average ACT English scores                                	|
# | **math_17**                    	| _float_  	| ACT 2017        	| The 2017 average ACT Math scores                                   	|
# | **read_17**                    	| _float_  	| ACT 2017        	| The 2017 average ACT Reading scores                                	|
# | **sci_17**                     	| _float_  	| ACT 2017        	| The 2017 average ACT Science scores                                	|
# | **comp_17**                    	| _float_  	| ACT 2017        	| The 2017 average Composite scores                                  	|
# | **part_18**                    	| _float_  	| ACT 2018        	| The 2018 average participation rate in the ACT                     	|
# | **eng_18**                     	| _float_  	| ACT 2018        	| The 2018 average ACT English scores                                	|
# | **math_18**                    	| _float_  	| ACT 2018        	| The 2018 average ACT Math scores                                   	|
# | **read_18**                    	| _float_  	| ACT 2018        	| The 2018 average ACT Reading scores                                	|
# | **sci_18**                     	| _float_  	| ACT 2018        	| The 2018 average ACT Science scores                                	|
# | **comp_18**                    	| _float_  	| ACT 2018        	| The 2018 average Composite scores                                  	|
# | **part_19**                    	| _float_  	| ACT 2019        	| The 2019 average participation rate in the ACT                     	|
# | **eng_19**                     	| _float_  	| ACT 2019        	| The 2019 average ACT English scores                                	|
# | **math_19**                    	| _float_  	| ACT 2019        	| The 2019 average ACT Math scores                                   	|
# | **read_19**                    	| _float_  	| ACT 2019        	| The 2019 average ACT Reading scores                                	|
# | **sci_19**                     	| _float_  	| ACT 2019        	| The 2018 average ACT Science scores                                	|
# | **comp_19**                    	| _float_  	| ACT 2019        	| The 2018 average Composite scores                                  	|
# | **part_20**                    	| _float_  	| ACT 2020        	| The 2020 average participation rate in the ACT                     	|
# | **eng_20**                     	| _float_  	| ACT 2020        	| The 2020 average ACT English scores                                	|
# | **math_20**                    	| _float_  	| ACT 2020        	| The 2020 average ACT Math scores                                   	|
# | **read_20**                    	| _float_  	| ACT 2020        	| The 2020 average ACT Reading scores                                	|
# | **sci_20**                     	| _float_  	| ACT 2020        	| The 2020 average ACT Science scores                                	|
# | **comp_20**                    	| _float_  	| ACT 2020        	| The 2020 average Composite scores                                  	|
# | **part_21**                    	| _float_  	| ACT 2021        	| The 2021 average participation rate in the ACT                     	|
# | **eng_21**                     	| _float_  	| ACT 2021        	| The 2021 average ACT English scores                                	|
# | **math_21**                    	| _float_  	| ACT 2021        	| The 2021 average ACT Math scores                                   	|
# | **read_21**                    	| _float_  	| ACT 2021        	| The 2021 average ACT Reading scores                                	|
# | **sci_21**                     	| _float_  	| ACT 2021        	| The 2021 average ACT Science scores                                	|
# | **comp_21**                    	| _float_  	| ACT 2021        	| The 2021 average Composite scores                                  	|
# | **part_22**                    	| _float_  	| ACT 2022        	| The 2022 average participation rate in the ACT                     	|
# | **eng_22**                     	| _float_  	| ACT 2022        	| The 2022 average ACT English scores                                	|
# | **math_22**                    	| _float_  	| ACT 2022        	| The 2022 average ACT Math scores                                   	|
# | **read_22**                    	| _float_  	| ACT 2022        	| The 2022 average ACT Reading scores                                	|
# | **sci_22**                     	| _float_  	| ACT 2022        	| The 2022 average ACT Science scores                                	|
# | **comp_22**                    	| _float_  	| ACT 2022        	| The 2022 average Composite scores                                  	|
# | **national_avg_participation** 	| _float_  	| ACT 2017 - 2022 	| The national average participation rates for ACT from 2017 to 2021 	|
# | **national_avg_english**       	| _float_  	| ACT 2017 - 2022 	| The national average English scores for ACT from 2017 to 2021      	|
# | **national_avg_math**          	| _float_  	| ACT 2017 - 2022 	| The national average Math scores for ACT from 2017 to 2021         	|
# | **national_avg_reading**       	| _float_  	| ACT 2017 - 2022 	| The national average Reading scores for ACT from 2017 to 2021      	|
# | **national_avg_science**       	| _float_  	| ACT 2017 - 2022 	| The national average Science scores for ACT from 2017 to 2021      	|
# | **national_avg_composite**     	| _float_  	| ACT 2017 - 2022 	| The national average Composite scores for ACT from 2017 to 2021    	|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### *Summary statistics of each dataframes:*

# %%
# First, this removes the first row of data from all the scores on national data. Only after removing, we're able to execute the summary statistics for all scores from 2017 to 2022.

allscores.drop(0, inplace=True)
allscores.head()
# Out:
#         state  part_17  eng_17  math_17  read_17  sci_17  comp_17  part_18  \
# 1     Alabama     1.00    18.9     18.4     19.7    19.4     19.2     1.00
# 2      Alaska     0.65    18.7     19.8     20.4    19.9     19.8     0.33
# 3     Arizona     0.62    18.6     19.8     20.1    19.8     19.7     0.66
# 4    Arkansas     1.00    18.9     19.0     19.7    19.5     19.4     1.00
# 5  California     0.31    22.5     22.7     23.1    22.2     22.8     0.27
#
#    eng_18  math_18  ...  math_21  read_21  sci_21  comp_21  part_22  eng_22  \
# 1    18.9     18.3  ...     18.0     19.2    18.8     18.7     1.00    17.3
# 2    19.8     20.6  ...     20.5     21.6    20.6     20.6     0.14    19.3
# 3    18.2     19.4  ...     19.8     20.3    19.9     19.8     0.64    17.3
# 4    19.1     18.9  ...     18.3     19.3    19.2     19.0     0.93    18.3
# 5    22.5     22.5  ...     25.6     26.6    25.5     26.1     0.04    26.9
#
#    math_22  read_22  sci_22  comp_22
# ...

# %%
allscores.describe().transpose()
# Out:
#          count       mean       std    min     25%    50%     75%   max
# part_17   51.0   0.652549  0.321408   0.08   0.310   0.69   1.000   1.0
# eng_17    51.0  20.931373  2.353677  16.30  19.000  20.70  23.300  25.5
# math_17   51.0  21.182353  1.981989  18.00  19.400  20.90  23.100  25.3
# read_17   51.0  22.013725  2.067271  18.10  20.450  21.80  24.150  26.0
# sci_17    51.0  21.450980  1.739353  18.20  19.950  21.30  23.200  24.9
# comp_17   51.0  21.519608  2.020695  17.80  19.800  21.40  23.600  25.5
# part_18   51.0   0.616471  0.340810   0.07   0.285   0.66   1.000   1.0
# eng_18    51.0  20.988235  2.446356  16.60  19.100  20.20  23.700  26.0
# math_18   51.0  21.125490  2.035765  17.80  19.400  20.70  23.150  25.2
# read_18   51.0  22.033333  2.164132  18.00  20.450  21.70  24.100  26.1
# sci_18    51.0  21.341176  1.870206  17.90  19.850  21.10  23.050  24.9
# comp_18   51.0  21.498039  2.117686  17.70  19.950  21.30  23.650  25.6
# ...

# %%
# First, this removes the first row of data from Participation on national data. Only after removing, we're able to execute the summary statistics for Participation rates from 2017 to 2022.

participation.drop(0, inplace=True)
participation.head()
# Out:
#         state  2017  2018  2019  2020  2021  2022
# 1     Alabama  1.00  1.00  1.00  1.00  1.00  1.00
# 2      Alaska  0.65  0.33  0.38  0.33  0.16  0.14
# 3     Arizona  0.62  0.66  0.73  0.71  0.35  0.64
# 4    Arkansas  1.00  1.00  1.00  1.00  0.99  0.93
# 5  California  0.31  0.27  0.23  0.19  0.05  0.04

# %%
participation.describe()
# Out:
#             2017       2018       2019       2020      2021       2022
# count  51.000000  51.000000  51.000000  51.000000  51.00000  51.000000
# mean    0.652549   0.616471   0.586667   0.569020   0.44549   0.460196
# std     0.321408   0.340810   0.345159   0.356428   0.36945   0.381479
# min     0.080000   0.070000   0.060000   0.050000   0.02000   0.020000
# 25%     0.310000   0.285000   0.245000   0.215000   0.09000   0.090000
# 50%     0.690000   0.660000   0.540000   0.460000   0.30000   0.300000
# 75%     1.000000   1.000000   1.000000   1.000000   0.85500   0.920000
# max     1.000000   1.000000   1.000000   1.000000   1.00000   1.000000

# %%
# This removes the first row of data from English on national data. Only after removing, we're able to execute the summary statistics for English scores from 2017 to 2022.

english.drop(0, inplace=True)
english.describe()
# Out:
#             2017       2018       2019       2020       2021       2022
# count  51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean   20.931373  20.988235  20.941176  20.929412  21.407843  21.027451
# std     2.353677   2.446356   2.525167   2.800307   3.327091   3.404707
# min    16.300000  16.600000  16.800000  16.700000  16.700000  16.100000
# 25%    19.000000  19.100000  18.850000  18.700000  18.700000  18.050000
# 50%    20.700000  20.200000  20.300000  20.100000  19.900000  19.700000
# 75%    23.300000  23.700000  23.700000  23.500000  25.200000  24.600000
# max    25.500000  26.000000  25.900000  26.300000  27.600000  27.400000

# %%
# This removes the first row of data from Math on national data. Only after removing, we're able to execute the summary statistics for Math scores from 2017 to 2022.

math.drop(0, inplace=True)
math.describe()
# Out:
#             2017       2018       2019       2020       2021       2022
# count  51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean   21.182353  21.125490  21.062745  21.043137  21.449020  20.919608
# std     1.981989   2.035765   2.102947   2.263383   2.722232   2.649152
# min    18.000000  17.800000  17.900000  17.700000  17.600000  17.100000
# 25%    19.400000  19.400000  19.300000  19.300000  19.500000  18.750000
# 50%    20.900000  20.700000  20.700000  20.100000  20.300000  20.000000
# 75%    23.100000  23.150000  23.100000  23.000000  24.450000  23.600000
# max    25.300000  25.200000  25.200000  25.600000  26.900000  25.600000

# %%
# This removes the first row of data from Reading on national data. Only after removing, we're able to execute the summary statistics for Reading scores from 2017 to 2022.

read.drop(0, inplace=True)
read.describe()
# Out:
#             2017       2018       2019       2020      2021       2022
# count  51.000000  51.000000  51.000000  51.000000  51.00000  51.000000
# mean   22.013725  22.033333  22.039216  22.149020  22.75098  22.339216
# std     2.067271   2.164132   2.257173   2.460112   3.06564   3.062357
# min    18.100000  18.000000  18.200000  18.300000  18.20000  17.800000
# 25%    20.450000  20.450000  20.300000  20.100000  20.30000  19.700000
# 50%    21.800000  21.700000  21.700000  21.800000  21.60000  21.400000
# 75%    24.150000  24.100000  24.350000  24.450000  25.80000  25.200000
# max    26.000000  26.100000  26.100000  26.600000  28.40000  28.200000

# %%
# This removes the first row of data from Science on national data. Only after removing, we're able to execute the summary statistics for Science scores from 2017 to 2022.

science.drop(0, inplace=True)
science.describe()
# Out:
#             2017       2018       2019       2020       2021       2022
# count  51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean   21.450980  21.341176  21.317647  21.386275  21.933333  21.501961
# std     1.739353   1.870206   1.971771   2.125937   2.558724   2.592025
# min    18.200000  17.900000  17.900000  18.100000  18.200000  17.600000
# 25%    19.950000  19.850000  19.650000  19.800000  20.000000  19.300000
# 50%    21.300000  21.100000  21.100000  20.800000  20.800000  20.400000
# 75%    23.200000  23.050000  23.300000  23.400000  24.550000  24.000000
# max    24.900000  24.900000  24.800000  25.400000  26.800000  26.000000

# %%
# This removes the first row of data from Composite on national data. Only after removing, we're able to execute the summary statistics for Composite scores from 2017 to 2022.

composite.drop(0, inplace=True)
composite.describe()
# Out:
#             2017       2018       2019       2020       2021       2022
# count  51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean   21.519608  21.498039  21.462745  21.505882  22.007843  21.572549
# std     2.020695   2.117686   2.192164   2.398450   2.910591   2.914384
# min    17.800000  17.700000  17.900000  17.900000  17.800000  17.300000
# 25%    19.800000  19.950000  19.800000  19.550000  19.750000  19.100000
# 50%    21.400000  21.300000  21.100000  20.900000  20.700000  20.500000
# 75%    23.600000  23.650000  23.700000  23.700000  25.100000  24.550000
# max    25.500000  25.600000  25.500000  26.000000  27.600000  26.900000

# %% [markdown]
# NOTE: Standard deviation for the National scores dataframe is not calculated, as the values represent the averages and summary from all the states' data.

# %% [markdown]
# ### *Data dictionary of standard deviation:*

# %%
# This formula creates a dictionary of the Participation standard deviation for each year.

participation_sd = {col:stdev_list(participation[col]) for col in participation.columns[1:]}
participation_sd
# Out:
# {'2017': 0.3182417575123181,
#  '2018': 0.33745194881997503,
#  '2019': 0.3417582373703047,
#  '2020': 0.3529164479354506,
#  '2021': 0.3658099459699665,
#  '2022': 0.37772014848675545}

# %%
# This formula creates a dictionary of the English scores standard deviation for each year.

english_sd = {col:stdev_list(english[col]) for col in english.columns[1:]}
english_sd
# Out:
# {'2017': 2.3304876369363363,
#  '2018': 2.4222536143202795,
#  '2019': 2.500288334007072,
#  '2020': 2.772716804419205,
#  '2021': 3.294311385525941,
#  '2022': 3.371162505687606}

# %%
# This formula creates a dictionary of the Math scores standard deviation for each year.

math_sd = {col:stdev_list(math[col]) for col in math.columns[1:]}
math_sd
# Out:
# {'2017': 1.9624620273436781,
#  '2018': 2.015707255555717,
#  '2019': 2.0822273881133406,
#  '2020': 2.2410829754227573,
#  '2021': 2.6954116822612524,
#  '2022': 2.623051628583203}

# %%
# This formula creates a dictionary of the Reading scores standard deviation for each year.

read_sd = {col:stdev_list(read[col]) for col in read.columns[1:]}
read_sd
# Out:
# {'2017': 2.0469029314842646,
#  '2018': 2.14280983452291,
#  '2019': 2.234934611612902,
#  '2020': 2.4358734431386373,
#  '2021': 3.0354359798636548,
#  '2022': 3.032185417229597}

# %%
# This formula creates a dictionary of the Science scores standard deviation for each year.

science_sd = {col:stdev_list(science[col]) for col in science.columns[1:]}
science_sd
# Out:
# {'2017': 1.7222161451443676,
#  '2018': 1.851779903767018,
#  '2019': 1.9523445816834186,
#  '2020': 2.104991230743518,
#  '2021': 2.533513925451667,
#  '2022': 2.5664876583422176}

# %%
# This formula creates a dictionary of the Composite scores standard deviation for each year.

composite_sd = {col:stdev_list(composite[col]) for col in composite.columns[1:]}
composite_sd
# Out:
# {'2017': 2.000786081581989,
#  '2018': 2.0968220768561987,
#  '2019': 2.1705660944369116,
#  '2020': 2.374819849902831,
#  '2021': 2.8819140655606708,
#  '2022': 2.885669693663919}

# %% [markdown]
# NOTE: Standard deviation for the All Scores and National scores dataframe is not calculated, as the values already represent the averages and summary from all the states' data.

# %% [markdown]
# ### *Trends in dataframes:*

# %%
# Before we use any function, let's take a look at the National average scores:

national
# Out:
#     national_avg  2017   2018   2019   2020   2021   2022
# 0  participation   0.6   0.52   0.48   0.46   0.35   0.36
# 0        english  20.3  20.20  20.10  20.10  19.60  19.00
# 0           math  20.7  20.50  20.40  20.40  19.90  19.30
# 0        reading  21.4  21.30  21.20  21.20  20.90  20.40
# 0        science  21.0  20.70  20.60  20.60  20.40  19.90
# 0      composite  21.0  20.80  20.70  20.70  20.30  19.80

# %% [markdown]
# In this table, we can see that all areas are trending downward in the last five years. Prior to the COVID-19 pandemic, the scores and participation rates were already declining. While there's a slight improvement in testing, but the overall scores continue to fall.
#
# Based on this table alone, one may deduce that the participation rate and scores are correlated - when one goes down, so will the other. But before we make any conclusions, let's take a closer look at the states and each subject.

# %%
# Using the multiple boolean masks, we can identify states with 100% participation rate in the ACT over the years.

participation[(participation['2017'] == 1.0) | (participation['2018'] == 1.0) | (participation['2019'] == 1.0) | (participation['2020'] == 1.0) | (participation['2021'] == 1.0) | (participation['2022'] == 1.0)]
# Out:
#              state  2017  2018  2019  2020  2021  2022
# 1          Alabama  1.00  1.00  1.00  1.00  1.00  1.00
# 4         Arkansas  1.00  1.00  1.00  1.00  0.99  0.93
# 6         Colorado  1.00  0.30  0.27  0.25  0.16  0.15
# 18        Kentucky  1.00  1.00  1.00  1.00  1.00  0.96
# 19       Louisiana  1.00  1.00  1.00  1.00  0.98  1.00
# 24       Minnesota  1.00  0.99  0.95  0.92  0.60  0.69
# 25     Mississippi  1.00  1.00  1.00  1.00  1.00  1.00
# 26        Missouri  1.00  1.00  0.82  0.78  0.63  0.66
# 27         Montana  1.00  1.00  1.00  1.00  0.70  0.94
# 28        Nebraska  0.84  1.00  1.00  1.00  0.86  0.94
# 29          Nevada  1.00  1.00  1.00  1.00  1.00  1.00
# 34  North Carolina  1.00  1.00  1.00  1.00  0.92  0.88
# 35    North Dakota  0.98  0.98  0.96  0.94  1.00  0.96
# 36            Ohio  0.75  1.00  1.00  1.00  0.85  0.82
# 37        Oklahoma  1.00  1.00  1.00  1.00  0.58  0.94
# 41  South Carolina  1.00  1.00  0.78  0.76  0.50  0.40
# ...

# %% [markdown]
# Based on the table above, we are seeing a few notable trends in the ACT participation rates:
# - Alabama, Mississippi, Nevada, and Tennessee were able to achieve 100% participation rate for six consecutive years. These states are located in the southern region and have implemented mandatory ACT tests for all high school students. ([*source*](https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice))
# - An increasing number of the states' participation rate dropped in 2021 and 2022 from a perfect 100% in the previous years. These states are Arkansas, Kentucky, Louisiana, Montana, Nebraska, North Carolina, Ohio, Oklahoma, Utah, Wisconsin and Wyoming - standardized tests are also mandated in most of these states.
# - Meanwhile, despite a perfect participation in 2017, Colorado saw noticeable and more significant dip in its participation rate from 2018 onwards. During that time period, Colorado started transitioning away from standardized exams to design the state's English and math tests. ([*source*](https://www.coloradoindependent.com/2017/07/06/from-csap-to-parcc-heres-how-colorados-standardized-tests-have-changed-and-whats-next/)) In more recent news, the state of Colorado removed standardized tests as an admission criteria to higher insitutions. ([*source*](https://leg.colorado.gov/bills/hb21-1067)) We can expect the participation rate in Colorado to decline or plateau in the coming years. It's likely that students who continue to take the ACT to fulfill scholarship criteria and also apply for out-of-state colleges that require standardized tests for admission.

# %%
# Using the sort function, we can identify states with lowest participation rate in the ACT over the years.

participation.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022']).head()
# Out:
#             state  2017  2018  2019  2020  2021  2022
# 20          Maine  0.08  0.07  0.06  0.05  0.02  0.02
# 30  New Hampshire  0.18  0.16  0.14  0.12  0.04  0.05
# 8        Delaware  0.18  0.17  0.13  0.11  0.05  0.05
# 40   Rhode Island  0.21  0.15  0.12  0.11  0.04  0.05
# 39   Pennsylvania  0.23  0.20  0.17  0.15  0.07  0.07

# %% [markdown]
# Based on the sorted table,
# - Maine had the lowest ACT participation rates for six consecutive years. Reason being, Maine has their own standardized test which they've revamped after changes in how students received their eduation during the pandemic ([*source*](https://www.mainepublic.org/maine/2021-02-02/maine-schools-plan-to-administer-revamped-standardized-tests-after-shelving-them-during-pandemic)) and they require all students to take the SAT. ([*source*](https://educationadvanced.com/resources/blog/list-of-standardized-tests-by-state/))
# - New Hampshire, Delaware, Rhode Island and Pennsylvania also had relatively low ACT participation rates compared to other states, and continue to decline. These states require students to take the SAT, which likely influenced the declining ACT testing. ([*source*](https://educationadvanced.com/resources/blog/list-of-standardized-tests-by-state/))

# %%
# Using the sort function, we can identify states with lowest average English scores in the ACT...

english.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022']).head()
# Out:
#              state  2017  2018  2019  2020  2021  2022
# 29          Nevada  16.3  16.6  16.8  16.7  16.7  16.1
# 41  South Carolina  17.5  17.3  18.0  17.3  17.4  17.8
# 34  North Carolina  17.8  18.0  17.8  17.3  17.3  17.1
# 12          Hawaii  17.8  18.2  17.9  17.2  16.8  17.6
# 25     Mississippi  18.2  18.2  18.1  17.8  17.5  17.2

# %%
# ...and highest average English scores in the ACT over the years.

english.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022'], ascending=False).head()
# Out:
#                    state  2017  2018  2019  2020  2021  2022
# 7            Connecticut  25.5  26.0  25.9  26.3  27.5  26.8
# 22         Massachusetts  25.4  25.5  25.5  26.0  27.6  26.6
# 30         New Hampshire  25.4  25.1  24.9  25.7  26.5  25.7
# 9   District of Columbia  24.4  23.7  23.6  23.2  25.8  27.4
# 20                 Maine  24.2  23.8  24.2  25.0  25.7  25.2

# %% [markdown]
# Based on the two sorted tables above for the average ACT English scores:
# - Nevada has the lowest average English scores across the five years. Mississippi also falls within the lowest five states, despite both Nevada and Mississippi having 100% participation rates consistently.
# - The top five states with the highest English scores are Connecticut, Massachusettes, New Hampshire, District of Columbia, and Maine - they are all located in the northeastern region as well. These states also saw gradual improvements in ACT scores over the six-year period.

# %%
# Using the sort function, we can identify states with lowest average Math scores in the ACT...

math.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022']).head()
# Out:
#              state  2017  2018  2019  2020  2021  2022
# 29          Nevada  18.0  17.8  18.0  18.0  17.7  17.1
# 25     Mississippi  18.1  18.1  17.9  17.7  17.6  17.4
# 1          Alabama  18.4  18.3  18.1  18.1  18.0  17.4
# 41  South Carolina  18.6  18.2  18.7  18.3  18.4  18.5
# 19       Louisiana  18.8  18.5  18.2  18.1  17.8  17.4

# %%
# ...and highest average Math scores in the ACT over the years.

math.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022'], ascending=False).head()
# Out:
#             state  2017  2018  2019  2020  2021  2022
# 22  Massachusetts  25.3  25.2  25.2  25.6  26.9  25.6
# 30  New Hampshire  25.1  24.7  24.7  25.2  25.9  25.0
# 7     Connecticut  24.6  24.8  24.7  25.1  26.2  25.3
# 33       New York  24.0  24.2  24.1  24.5  25.7  24.6
# 20          Maine  24.0  23.6  23.8  24.0  24.4  23.7

# %% [markdown]
# For the ACT Math scores:
# - Nevada, Mississippi and Alabama had the lowest Math scores in the US, despite the perfect participation rates.
# - The northeastern states continue to top the list for Math scores across the US.

# %%
# Using the sort function, we can identify states with lowest average Reading scores in the ACT...

read.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022']).head()
# Out:
#              state  2017  2018  2019  2020  2021  2022
# 29          Nevada  18.1  18.0  18.2  18.3  18.2  17.8
# 25     Mississippi  18.8  18.9  18.9  18.5  18.4  18.2
# 41  South Carolina  19.1  18.6  19.4  19.0  19.2  19.6
# 12          Hawaii  19.2  19.1  19.2  19.1  18.6  19.4
# 34  North Carolina  19.6  19.5  19.4  19.5  19.4  19.2

# %%
# ...and highest average Reading scores in the ACT over the years.

read.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022'], ascending=False).head()
# Out:
#                    state  2017  2018  2019  2020  2021  2022
# 30         New Hampshire  26.0  25.6  25.6  26.2  27.4  26.5
# 22         Massachusetts  25.9  25.9  26.1  26.6  28.4  27.3
# 7            Connecticut  25.6  26.1  26.1  26.5  28.0  27.1
# 9   District of Columbia  24.9  24.4  24.4  23.9  26.8  28.2
# 20                 Maine  24.8  24.7  25.1  25.8  26.8  26.2

# %% [markdown]
# Similar to the English scores, states with the highest and lowest Reading scores are similar. These indicate that the scores may be related to each other - see plots below.

# %%
# Using the sort function, we can identify states with lowest average Science scores in the ACT...

science.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022']).head()
# Out:
#              state  2017  2018  2019  2020  2021  2022
# 29          Nevada  18.2  17.9  17.9  18.1  18.2  17.6
# 25     Mississippi  18.8  18.6  18.4  18.4  18.3  18.0
# 41  South Carolina  18.9  18.5  18.9  18.6  18.9  19.1
# 12          Hawaii  19.3  19.0  19.2  18.7  18.7  19.1
# 34  North Carolina  19.3  19.2  19.0  18.9  19.3  18.8

# %%
# ...and highest average Science scores in the ACT over the years.

science.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022'], ascending=False).head()
# Out:
#             state  2017  2018  2019  2020  2021  2022
# 30  New Hampshire  24.9  24.4  24.5  25.3  26.1  25.2
# 22  Massachusetts  24.7  24.7  24.8  25.4  26.8  25.8
# 7     Connecticut  24.6  24.9  24.8  25.3  26.4  25.7
# 33       New York  23.9  24.2  24.4  24.6  25.9  25.0
# 23       Michigan  23.8  23.9  24.0  24.1  24.6  24.2

# %% [markdown]
# Similar to the English and Reading scores, states with the lowest Science scores are similar. While the northeastern states continue to top the list for highest Science scores, Michigan, a midwestern state also made the top five in the list.

# %%
# Using the sort function, we can identify states with lowest average Composite scores in the ACT...

composite.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022']).head()
# Out:
#              state  2017  2018  2019  2020  2021  2022
# 29          Nevada  17.8  17.7  17.9  17.9  17.8  17.3
# 25     Mississippi  18.6  18.6  18.4  18.2  18.1  17.8
# 41  South Carolina  18.7  18.3  18.8  18.4  18.6  18.9
# 12          Hawaii  19.0  18.9  19.0  18.5  18.2  18.8
# 34  North Carolina  19.1  19.1  19.0  18.8  18.9  18.5

# %%
# ...and highest average Composite scores in the ACT over the years.

composite.sort_values(by=['2017', '2018', '2019', '2020', '2021', '2022'], ascending=False).head()
# Out:
#             state  2017  2018  2019  2020  2021  2022
# 30  New Hampshire  25.5  25.1  25.0  25.7  26.6  25.7
# 22  Massachusetts  25.4  25.5  25.5  26.0  27.6  26.5
# 7     Connecticut  25.2  25.6  25.5  25.9  27.2  26.3
# 20          Maine  24.3  24.0  24.3  24.9  25.6  25.1
# 33       New York  24.2  24.5  24.5  24.9  26.3  25.3

# %% [markdown]
# Based on the individual subjects' scores earlier, there's no surprise that:
# - States with lowest composite scores are Nevada, Mississippi, South Carolina, Hawaii, and North Carolina. While Nevada and Mississippi saw perfect participation rates, these appear to be independent with how the students are performing in the ACT.
# - States with highest composite scores are New Hampshire, Massachusettes, Connecticut, Maine, and New York. These states also show improvement in average scores over the years, but most of them saw a small decline from 2021 to 2022.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# The below formula creates a heatmap of the ACT features from 2017 to 2022, with the following function:

# Heatmap plot
plt.figure(figsize=(18,14), dpi= 80)
sns.heatmap(allscores.corr(), xticklabels=allscores.corr().columns, yticklabels=allscores.corr().columns, cmap='Pastel1', center=0, annot=True)

# Heatmap decorations
plt.title('Heatmap of features in the ACT from 2017 to 2021', fontsize=16)
plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.show()

# %% [markdown]
# Based on the heatmap, there are two observable trends:
# - Participation rate is negatively correlated to the subject scores - states with higher ACT participation rate also saw lower scores overall. However, these may not cause or influence each other. States that enforce mandatory testing would observe lower average scores than states that kept to test-optional. When wider group of students have to take the tests the data would be more varied. On the other hand, if students are not required but choose to take the exams, they may have other reasons, e.g. scholarship requirement, boost college admission chances.
# - Meanwhile, subject scores from one year to another are positively correlated, which means that states' performance in certain subjects will be about the same or change slightly in the following years. The impact of any new academic policies and teaching styles will take time, so it's unlikely to see huge leaps in scores within a short timeframe.

# %%
# The below formula creates multiple histograms of the ACT features from 2017 to 2022, with the following function:

def multi_histo(dataframe, columnslist, chart_titles, xlabels, sharex=False, kde=False, figsize=(14,7)):
    nrows = int(np.ceil(len(columnslist)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=figsize, sharex=sharex, sharey=True)
    ax = ax.ravel() 
    
    for value, column in enumerate(columnslist):
        mean = np.mean(dataframe[columnslist[value]])
        ax[value].axvline(mean, ls='--', color='red')
        
        sns.histplot(data=dataframe, x=column, ax=ax[value], kde=kde, bins=8)
        ax[value].set_title(chart_titles[value] + f' (Mean: {mean:.1f})')
        ax[value].set_xlabel(xlabels[value])
        if value % 2 == 0:
            ax[value].set_ylabel('No. States')
    
    fig.tight_layout(h_pad = 1.5, w_pad = 1.5)

# %%
# This formula creates histograms of participation rates from 2017 to 2022.

multi_histo(allscores, ['part_17', 'part_18', 'part_19', 'part_20', 'part_21', 'part_22'], ['ACT 2017 Participation Rate', 'ACT 2018 Participation Rate', 'ACT 2019 Participation Rate', 'ACT 2020 Participation Rate', 'ACT 2021 Participation Rate', 'ACT 2022 Participation Rate'], ['Participation', 'Participation', 'Participation', 'Participation', 'Participation', 'Participation'], sharex=True, kde=True)

# %% [markdown]
# The overall distribution of participation rates do not show any notable trends, but we can see that:
# - Participation rate of 90-100% gradually decreased over the years.
# - Participation rate of 0-10% gradually increased over the years.
#
# Both of these changes are in line with increasing number of US colleges enforcing test-optional policies. ([*source*](https://www.highereddive.com/news/over-1700-colleges-wont-require-sat-act-for-fall-2023-up-from-same-poin/628267/))
# More Virginia colleges are also enforcing test-optional policy ([*source*](https://www.virginiamercury.com/2022/10/31/more-virginia-colleges-make-sat-act-exams-optional/)).

# %%
# This formula creates histograms of English scores from 2017 to 2022.

multi_histo(allscores, ['eng_17', 'eng_18', 'eng_19', 'eng_20', 'eng_21', 'eng_22'], ['ACT 2017 English Scores', 'ACT 2018 English Scores', 'ACT 2019 English Scores', 'ACT 2020 English Scores', 'ACT 2021 English Scores', 'ACT 2022 English Scores'], ['English Scores', 'English Scores', 'English Scores', 'English Scores', 'English Scores', 'English Scores'], sharex=True, kde=True)

# %% [markdown]
# The distribution of English scores are not normally distributed. Most of these charts appear close to bimodal, with two noticeable peaks on lower end and higher end of overall scores.

# %%
# This formula creates histograms of Math scores from 2017 to 2022.

multi_histo(allscores, ['math_17', 'math_18', 'math_19', 'math_20', 'math_21', 'math_22'], ['ACT 2017 Math Scores', 'ACT 2018 Math Scores', 'ACT 2019 Math Scores', 'ACT 2020 Math Scores', 'ACT 2021 Math Scores', 'ACT 2022 Math Scores'], ['Math Scores', 'Math Scores', 'Math Scores', 'Math Scores', 'Math Scores', 'Math Scores'], sharex=True, kde=True)

# %% [markdown]
# The distribution of Math scores are not normally distributed. Most of these charts appear close to bimodal, with two noticeable peaks on lower end and higher end of overall scores.

# %%
# This formula creates histograms of Reading scores from 2017 to 2022.

multi_histo(allscores, ['read_17', 'read_18', 'read_19', 'read_20', 'read_21', 'read_22'], ['ACT 2017 Reading Scores', 'ACT 2018 Reading Scores', 'ACT 2019 Reading Scores', 'ACT 2020 Reading Scores', 'ACT 2021 Reading Scores', 'ACT 2022 Reading Scores'], ['Reading Scores', 'Reading Scores', 'Reading Scores', 'Reading Scores', 'Reading Scores', 'Reading Scores'], sharex=True, kde=True)

# %% [markdown]
# From 2017 to 2020, the distribution of Reading scores appear close to normal distribution. However the overall Reading scores are not normally distributed and appear bimodal.

# %%
# This formula creates histograms of Science scores from 2017 to 2022.

multi_histo(allscores, ['sci_17', 'sci_18', 'sci_19', 'sci_20', 'sci_21', 'sci_22'], ['ACT 2017 Science Scores', 'ACT 2018 Science Scores', 'ACT 2019 Science Scores', 'ACT 2020 Science Scores', 'ACT 2021 Science Scores', 'ACT 2022 Science Scores'], ['Science Scores', 'Science Scores', 'Science Scores', 'Science Scores', 'Science Scores', 'Science Scores'], sharex=True, kde=True)

# %% [markdown]
# From 2017 to 2018, the distribution of Science scores appear like normal distribution. However the overall Science scores from 2019 onwards are not normally distributed and appear bimodal.

# %%
# This formula creates histograms of Composite scores from 2017 to 2022.

multi_histo(allscores, ['comp_17', 'comp_18', 'comp_19', 'comp_20', 'comp_21', 'comp_22'], ['ACT 2017 Composite Scores', 'ACT 2018 Composite Scores', 'ACT 2019 Composite Scores', 'ACT 2020 Composite Scores', 'ACT 2021 Composite Scores', 'ACT 2022 Composite Scores'], ['Composite Scores', 'Composite Scores', 'Composite Scores', 'Composite Scores', 'Composite Scores', 'Composite Scores'], sharex=True, kde=True)

# %% [markdown]
# The distribution of Composite scores are not normally distributed. Most of these charts appear close to bimodal, with two noticeable peaks on lower end and higher end of overall scores.

# %%
# The below formula creates multiple boxplots of the ACT features from 2017 to 2022, with the following function:

def multi_boxplots(dataframe, columnslist, yticklabels, chart_title, xlabel, test_type=False, palette='pastel', orient='h'):
    plt.figure(figsize=(14,7))
    plt.title(chart_title)
    palette="pastel"
    
    ax = sns.boxplot(data=dataframe[columnslist],palette=palette, orient=orient)
    ax.set_yticklabels(yticklabels)
    ax.set_xlabel(xlabel)

# %%
# This formula creates boxplots of participation rates from 2017 to 2022.

multi_boxplots(allscores, ['part_17', 'part_18', 'part_19', 'part_20', 'part_21', 'part_22'], ['2017', '2018', '2019', '2020', '2021', '2022'], 'ACT Participation Rate 2017-2022', 'Participation Rate', test_type=True)

# %% [markdown]
# From 2017 to 2020, the participation rates are left-skewed where more students were taking the ACT. The distribution in 2021 and 2022 appear more symmetrical as more students skip the standardized tests and colleges enforcing test-optional policy. This chart also shows that the median for participation rates decreases gradually every year, in line with our early data and findings.

# %%
# This formula creates boxplots of English scores from 2017 to 2022.

multi_boxplots(allscores, ['eng_17', 'eng_18', 'eng_19', 'eng_20', 'eng_21', 'eng_22'], ['2017', '2018', '2019', '2020', '2021', '2022'], 'ACT English Scores 2017-2022', 'English Scores', test_type=True)

# %% [markdown]
# The English scores overall appear symmetical, though we can see that the median is gradually decreasing each year. In 2021 and 2022, we can see that the data is more spread out compared to earlier years.

# %%
# This formula creates boxplots of Math scores from 2017 to 2022.

multi_boxplots(allscores, ['math_17', 'math_18', 'math_19', 'math_20', 'math_21', 'math_22'], ['2017', '2018', '2019', '2020', '2021', '2022'], 'ACT Math Scores 2017-2022', 'Math Scores', test_type=True)

# %% [markdown]
# Similar to English scores, the Math scores overall appear symmetical. The median is also gradually decreasing each year and the scores are more spread out in 2021 and 2022.

# %%
# This formula creates boxplots of Reading scores from 2017 to 2022.

multi_boxplots(allscores, ['read_17', 'read_18', 'read_19', 'read_20', 'read_21', 'read_22'], ['2017', '2018', '2019', '2020', '2021', '2022'], 'ACT Reading Scores 2017-2022', 'Reading Scores', test_type=True)

# %% [markdown]
# Similar to English and Math scores, the Reading scores overall appear symmetical. The median is also gradually decreasing each year and the scores are more spread out in 2021 and 2022.

# %%
# This formula creates boxplots of Science scores from 2017 to 2022.

multi_boxplots(allscores, ['sci_17', 'sci_18', 'sci_19', 'sci_20', 'sci_21', 'sci_22'], ['2017', '2018', '2019', '2020', '2021', '2022'], 'ACT Science Scores 2017-2022', 'Science Scores', test_type=True)

# %% [markdown]
# Similar to other subject scores, the Science scores overall appear symmetical. The median is also gradually decreasing each year and the scores are more spread out in 2021 and 2022.

# %%
# This formula creates boxplots of Composite scores from 2017 to 2022.

multi_boxplots(allscores, ['comp_17', 'comp_18', 'comp_19', 'comp_20', 'comp_21', 'comp_22'], ['2017', '2018', '2019', '2020', '2021', '2022'], 'ACT Composite Scores 2017-2022', 'Composite Scores', test_type=True)

# %% [markdown]
# In line with the other subjects, the score boxplots are symmetrical with gradually decreasing median. 2021 and 2022 data are more spread out.

# %%
# The below formula creates multiple scatter plots of the ACT features from 2017 to 2022, with the following function:

def multi_scatter(dataframe, list_x, list_y, chart_titles, xlabels, ylabels, sharex = False, sharey = False):
    if len(list_x) == 1:
        ncols = 1
    else:
        ncols = 2
    nrows = int(np.ceil(len(list_x)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(16,18), sharex = sharex, sharey = sharey)
    ax = ax.ravel() 
    
    for value, column in enumerate(list_x):
        sns_fig = sns.regplot(data=dataframe, x=list_x[value], y=list_y[value], ax=ax[value]).set_title(chart_titles[value])
        ax[value].set_xlabel(xlabels[value])
        ax[value].set_ylabel(ylabels[value])
        plt.tight_layout()

# %%
# This formula creates scatterplots of participation rates against Composite scores from 2017 to 2022.

multi_scatter(allscores, ['part_17', 'part_18', 'part_19', 'part_20', 'part_21', 'part_22'], ['comp_17', 'comp_18', 'comp_19', 'comp_20', 'comp_21', 'comp_22'], ['2017 ACT Participation Rate vs Composite Scores', '2018 ACT Participation Rate vs Composite Scores', '2019 ACT Participation Rate vs Composite Scores', '2020 ACT Participation Rate vs Composite Scores', '2021 ACT Participation Rate vs Composite Scores', '2022 ACT Participation Rate vs Composite Scores'], ['Participation Rate', 'Participation Rate', 'Participation Rate', 'Participation Rate', 'Participation Rate', 'Participation Rate'], ['Composite Scores', 'Composite Scores', 'Composite Scores', 'Composite Scores', 'Composite Scores', 'Composite Scores'], sharex = True, sharey= True)

# %% [markdown]
# Similar to the earlier heatmap, the participation rate and composite score demonstrate negative correlation.

# %%
# This formula creates scatterplots of English vs Reading scores from 2017 to 2022.

multi_scatter(allscores, ['eng_17', 'eng_18', 'eng_19', 'eng_20', 'eng_21', 'eng_22'], ['read_17', 'read_18', 'read_19', 'read_20', 'read_21', 'read_22'], ['2017 ACT English vs Reading Scores', '2018 ACT English vs Reading Scores', '2019 ACT English vs Reading Scores', '2020 ACT English vs Reading Scores', '2021 ACT English vs Reading Scores', '2022 ACT English vs Reading Scores'], ['English Scores', 'English Scores', 'English Scores', 'English Scores', 'English Scores', 'English Scores'], ['Reading Scores', 'Reading Scores', 'Reading Scores', 'Reading Scores', 'Reading Scores', 'Reading Scores'], sharex = True, sharey= True)

# %% [markdown]
# Based on scatter plots, English and Reading scores appear to be positively correlated to each other. When a student does well in the English section, he/she is likely to do well in Reading as well. This indicates potential overlap in the subjects and the test administrator may want to consider reviewing the test format.

# %%
# This formula creates scatterplots of Math vs Science scores from 2017 to 2022.

multi_scatter(allscores, ['math_17', 'math_18', 'math_19', 'math_20', 'math_21', 'math_22'], ['sci_17', 'sci_18', 'sci_19', 'sci_20', 'sci_21', 'sci_22'], ['2017 ACT Math vs Science Scores', '2018 ACT Math vs Science Scores', '2019 ACT Math vs Science Scores', '2020 ACT Math vs Science Scores', '2021 ACT Math vs Science Scores', '2022 ACT Math vs Science Scores'], ['Math Scores', 'Math Scores', 'Math Scores', 'Math Scores', 'Math Scores', 'Math Scores'], ['Science Scores', 'Science Scores', 'Science Scores', 'Science Scores', 'Science Scores', 'Science Scores'], sharex = True, sharey= True)

# %% [markdown]
# The Math and Science scores are positively correlated. When a student does well in Math, they are likely to do well in Science. However these are two different subjects and it may not make sense to combine these sections. The Science section of the ACT requires basic level of understanding across different scientific disciplines. ([*source*](https://www.usnews.com/education/blogs/college-admissions-playbook/articles/what-to-know-about-the-act-science-section))
#
# Students applying for Science-related majors may need to present their Science scores to be eligible for admission and/or scholarship.

# %% [markdown]
# ![ACT_tested_2022.jpg](attachment:ACT_tested_2022.jpg)

# %% [markdown]
# The above map shows that:
# - States with higher ACT testing rates for the ACT are in the west, midwest and southern regions, e.g. Nevada, Montana, Oklahoma, Mississippi.
# - States outside of the US mainland, Alaska and Hawaii also saw high testing rates for the ACT.
# - States with lowest ACT testing rates in the East Coast and West Coast areas, e.g. Maine, New York, California, Oregon, Washington, etc.
#
# Map was taken from ACT 2022 Data Visualization: ([*source*](https://tableauprototypes.act.org/t/ACTExternal/views/ACTProfileReport2022/PercentTestedbyState?%3Aembed=y&%3Adisplay_count=n&%3AshowVizHome=n&%3Aorigin=viz_share_link))

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# In summary, the analysis of ACT scores from 2017 to 2022 has shown that:
# 1. The participation rate are negatively related to ACT scores, and they are nearly independent. The influence of participation rate on performance is minimal, and improving participation rate will not necessarily improve scores because,
#  - States that enforce mandatory testing will have a more diverse group of students taking the tests - hence lowering the average scores.
#  - Students in test-optional states who choose to take the ACT are likely to be strong in academic tests, and they may be doing it for scholarship or to boost their college application.
#  - Many states have their own statewide tests that students are required to take; it’s not efficient to study for multiple standardized tests.
#  - With more colleges enforcing test-optional policy, students may choose to skip the tests so they can focus on their ongoing education and other admission criteria.
# 2. English and Reading subjects appear to overlap in terms of average scores and trends - indicating that the ACT board could consider reviewing the format of the test and condense further. This may help incentivize more students to take the ACT.
# 3. While Math and Science scores appear to overlap, however it is not feasible to combine the tests as the subject matters vary greatly. Students looking to specialise in Math- or Science-related majors will likely need the separate scores for their college admission or scholarship application.
#
# **Recommendations**
# 1. To review the need for mandatory statewide standardized tests and assess how to best help students of different abilities/potential learn.
# 2. If the mandatory testing policies are meant to drive interest in higher education, schools can encourage students to leverage the colleges’ test-optional policies and apply to more colleges.
# 3. However if the tests are meant to boost academic standards, state education departments and schools need to recognize different ways to do that and instill an interest in learning, for example, through projects, laboratory time, assignments, etc.
# 4. Take a more holistic approach to measuring students’ readiness for college, e.g. GPA scores, essays, interviews, advanced-level classes credits, extracurricular activities, passion projects/ hobbies.
